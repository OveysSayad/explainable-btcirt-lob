# %% [markdown]
# # Data audit\n\nNotebooks import reusable logic from `src/` — do not duplicate pipeline code.\n

# %%
from src.data_loader import load_btcirt, summarize_raw_catalog
from src.config import load_config, resolve_paths
print("Use python -m src.pipeline for full results.")\n
