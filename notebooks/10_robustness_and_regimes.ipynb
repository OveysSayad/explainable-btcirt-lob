# %% [markdown]
# # Robustness\n\nNotebooks import reusable logic from `src/` — do not duplicate pipeline code.\n

# %%
# See reports/tables/regime_performance.csv after pipeline run
print("Use python -m src.pipeline for full results.")\n
